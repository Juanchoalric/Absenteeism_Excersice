# %%
from absenteeism_module import *

# %%
df = pd.read_csv('Absenteeism_new_data.csv')

# %%
df.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# 2                12   34                  237.656               25          1
# 3                22   40                  237.656               22          2
# 4                12   34                  237.656               25          1
#
#    Children  Pets
# 0         0     0
# 1         1     4
# 2         2     0
# 3         2     0
# 4         2     0

# %%
model = absenteeism_model('model_tree', 'scaler_tree')
# Out:
# /home/juanchoalric/.pyenv/versions/3.6.9/envs/global/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.19.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/juanchoalric/.pyenv/versions/3.6.9/envs/global/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator StandardScaler from version 0.19.1 when using version 0.19.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
df2 = model.predicted_outputs()

# %%
df2.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0       0.0         0         1            6
# 1         1       0.0         0         0            6
# 2         0       0.0         0         1            6
# 3         0       0.0         0         1            6
# 4         1       0.0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.122799           0
# 1     0.873392           1
# 2     0.268305           0
# 3     0.196385           0
# 4     0.723502           1

# %%
df2.to_csv('Absenteeism_tree_predictions.csv', index=False)
